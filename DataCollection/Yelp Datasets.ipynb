# %%
import os
import json
import pandas as pd
import dask.dataframe as dd
from PIL import Image
import matplotlib.pyplot as plt

# %%
filename = "yelp_academic_dataset_review" + ".json"
path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

df_review = pd.read_json(path, lines=True, chunksize=100000)

chunks = []

for i, chunk in enumerate(df_review):
    # print(f"Processing chunk {i+1}")
    chunks.append(chunk)
    
    if i == 9:
        break
    
chunk_review = pd.concat(chunks, ignore_index=True)

chunk_review.shape
# Out:
# (1000000, 9)

# %%
filename = "yelp_academic_dataset_review_subset" + ".csv"
out_path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

chunk_review.to_csv(out_path, index=False)

# %%
filename = "yelp_academic_dataset_user" + ".json"
path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

df_user = pd.read_json(path, lines=True, chunksize=100000)

user_chunks = []

for i, chunk in enumerate(df_user):
    # print(f"Processing chunk {i+1}")
    user_chunks.append(chunk)
    
    if i == 9:
        break
    
chunk_user = pd.concat(user_chunks, ignore_index=True)

chunk_user.shape
# Out:
# (1000000, 22)

# %%
filename = "yelp_academic_dataset_user_subset" + ".csv"
out_path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

chunk_user.to_csv(out_path, index=False)

# %%
filename = "yelp_academic_dataset_business" + ".json"
path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

df_business = pd.read_json(path, lines=True, chunksize=100000)

business_chunks = []

for i, chunk in enumerate(df_business):
    # print(f"Processing chunk {i+1}")
    business_chunks.append(chunk)
    
    if i == 9:
        break
    
chunk_business = pd.concat(business_chunks, ignore_index=True)

chunk_business.shape
# Out:
# (150346, 14)

# %%
filename = "yelp_academic_dataset_business" + ".csv"
out_path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

chunk_business.to_csv(out_path, index=False)

# %%
filename = "yelp_academic_dataset_checkin" + ".json"
path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

df_checkin = pd.read_json(path, lines=True, chunksize=100000)

checkin_chunks = []

for i, chunk in enumerate(df_checkin):
    # print(f"Processing chunk {i+1}")
    checkin_chunks.append(chunk)
    
    if i == 9:
        break
    
chunk_checkin = pd.concat(checkin_chunks, ignore_index=True)

chunk_checkin.shape
# Out:
# (131930, 2)

# %%
filename = "yelp_academic_dataset_checkin" + ".csv"
out_path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

chunk_checkin.to_csv(out_path, index=False)

# %%
filename = "yelp_academic_dataset_tip" + ".json"
path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

df_tip = pd.read_json(path, lines=True, chunksize=100000)

tip_chunks = []

for i, chunk in enumerate(df_tip):
    # print(f"Processing chunk {i+1}")
    tip_chunks.append(chunk)
    
    if i == 9:
        break
    
chunk_tip = pd.concat(tip_chunks, ignore_index=True)

chunk_tip.shape
# Out:
# (908915, 5)

# %%
filename = "yelp_academic_dataset_tip" + ".csv"
out_path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

chunk_tip.to_csv(out_path, index=False)

# %%
import tarfile


tar_file_path = "C:/Users/tokud/Downloads/yelp_photos.tar"
extract_dir = "C:/Users/tokud/Downloads/extracted_yelp_photos/photos"
output_dir = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)


# Function to extract images from the .tar file in chunks
def extract_in_chunks(tar_path, extract_to, output_directory, chunk_size=1000):
    with tarfile.open(tar_path, "r") as tar:
        members = tar.getmembers()  # Get the list of files inside the .tar file
        total_files = len(members)
        print(f"Total number of files: {total_files}")
        
        for i in range(0, total_files, chunk_size):
            chunk = members[i:i + chunk_size]  # Get a chunk of files
            tar.extractall(path=extract_to, members=chunk)  # Extract the chunk
            print(f"Extracted {i + chunk_size} files")
            
            # Process and display images after each chunk is extracted
            process_images_and_display(extract_to, output_directory)
            
            # Optionally break after the first chunk for testing
            break

# Function to process images in chunks from the extracted folder
def process_images(directory, chunk_size):
    count = 0
    image_chunk = []
    
    for image_file in os.listdir(directory):
        if image_file.endswith('.jpg'):
            img_path = os.path.join(directory, image_file)
            img = Image.open(img_path)
            image_chunk.append((img, image_file))
            count += 1
            
            if count >= chunk_size:  # When the chunk is filled, yield it
                yield image_chunk
                image_chunk = []  # Reset the chunk
                count = 0
    
    # Yield any remaining images (if fewer than chunk_size)
    if image_chunk:
        yield image_chunk
        


# Function to display the images
def display_images(image_list, num_images_to_display=10):
    # Select only the first 'num_images_to_display' images
    selected_images = [img for img, _ in image_list[:num_images_to_display]]

    # Set up the plotting grid
    plt.figure(figsize=(15, 10))
    
    for i, img in enumerate(selected_images):
        plt.subplot(2, 5, i + 1)  # 2 rows and 5 columns grid
        plt.imshow(img)
        plt.axis('off')  # Hide axes
        plt.title(f"Image {i + 1}")

    plt.show()

# Function to process and display images after extraction

def process_images_and_display(directory, output_directory):
    for image_chunk in process_images(directory, chunk_size=100):
        # Display images
        display_images(image_chunk, num_images_to_display=10)

        # Save images to the output directory
        for img, image_name in image_chunk:
            save_path = os.path.join(output_directory, image_name)
            img.save(save_path)  # Save the image to the output folder
            print(f"Saved {image_name} to {save_path}")
        
        break  # Only process the first chunk (you can remove this to process more)


# Extract files in chunks of 1000 and process them
extract_in_chunks(tar_file_path, extract_dir, output_dir, chunk_size=1000)
# Out:
# Total number of files: 200101
# Extracted 1000 files
# Saved --5V3mRlhb3zqE5yF4Gpaw.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--5V3mRlhb3zqE5yF4Gpaw.jpg
# Saved --9cH8_rrskfmYvONaJpgQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--9cH8_rrskfmYvONaJpgQ.jpg
# Saved --9zKbcEd-DXH4ZUiEI4UA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--9zKbcEd-DXH4ZUiEI4UA.jpg
# Saved --dacvi4Y_8ACp-10nafMA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--dacvi4Y_8ACp-10nafMA.jpg
# Saved --e8vgtonVwPXG3n6lfBLA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--e8vgtonVwPXG3n6lfBLA.jpg
# Saved --GXT_8apxBAs7epcHf-zA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--GXT_8apxBAs7epcHf-zA.jpg
# Saved --hMxFnB1b_UeDwzsOCmCA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--hMxFnB1b_UeDwzsOCmCA.jpg
# Saved --IHD2ZgFPfFMR4qMkLzFA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--IHD2ZgFPfFMR4qMkLzFA.jpg
# Saved --MwzZ4ODNvGO877myxJsg.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--MwzZ4ODNvGO877myxJsg.jpg
# Saved --Oz_XBrbYJa1RgEfo6Msw.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--Oz_XBrbYJa1RgEfo6Msw.jpg
# Saved --wxyCFpNg13pVl00xvlXg.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--wxyCFpNg13pVl00xvlXg.jpg
# Saved --Ynyj3xLwWbnUwe-fumow.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--Ynyj3xLwWbnUwe-fumow.jpg
# Saved --zScnI03KioBVMtcOK6oQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\--zScnI03KioBVMtcOK6oQ.jpg
# Saved -0-Sor-tVeKH_KXSWI8SMw.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-0-Sor-tVeKH_KXSWI8SMw.jpg
# Saved -018xGxpxVLDmE3tVmAzbw.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-018xGxpxVLDmE3tVmAzbw.jpg
# Saved -05_WZmAEOEVfS9FnIgA9g.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-05_WZmAEOEVfS9FnIgA9g.jpg
# Saved -0a3-Q_8j9YwWenJlmNt-Q.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-0a3-Q_8j9YwWenJlmNt-Q.jpg
# Saved -0A6_xM5K-YK8wwnGgBpEQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-
.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-537WBDBda_59duWCrJ5qA.jpg
# Saved -5eWEGBUCDMy2Yf2NK0Lbw.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-5eWEGBUCDMy2Yf2NK0Lbw.jpg
# Saved -5KVuLNs1sSPRCFJp3IyzA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-5KVuLNs1sSPRCFJp3IyzA.jpg
# Saved -5oIp8ydAAIitiQHD6PPHQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-5oIp8ydAAIitiQHD6PPHQ.jpg
# Saved -5_uBCUQLNW-nakQSX1ZFA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-5_uBCUQLNW-nakQSX1ZFA.jpg
# Saved -61FulfYz-UTQ_Y3qJCLlA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-61FulfYz-UTQ_Y3qJCLlA.jpg
# Saved -6bwc62e0M33F6yFfwkRFQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-6bwc62e0M33F6yFfwkRFQ.jpg
# Saved -6e7O_MxoRNhnR_9b7w8Vw.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-6e7O_MxoRNhnR_9b7w8Vw.jpg
# Saved -6Q0oKzLXdpdUPZg5MKirA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-6Q0oKzLXdpdUPZg5MKirA.jpg
# Saved -6ri4RX_6qVoX45OA4degA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-6ri4RX_6qVoX45OA4degA.jpg
# Saved -6vTQzK9BSSRadnkKTBIow.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-6vTQzK9BSSRadnkKTBIow.jpg
# Saved -6Wc50yIwuTZD7KaydUREQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-6Wc50yIwuTZD7KaydUREQ.jpg
# Saved -7bLHhKejT1mJMzeQ5Qm8w.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7bLHhKejT1mJMzeQ5Qm8w.jpg
# Saved -7BwhnqonTWwu7qg6e3Ujg.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7BwhnqonTWwu7qg6e3Ujg.jpg
# Saved -7cTcmGZTL_OsggYgtbq6Q.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7cTcmGZTL_OsggYgtbq6Q.jpg
# Saved -7CYPJxI98uAm7wyouDB1g.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7CYPJxI98uAm7wyouDB1g.jpg
# Saved -7D58AE88NXMyavZRzdhyg.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7D58AE88NXMyavZRzdhyg.jpg
# Saved -7GT2pKgPoMK4tfO-Mciaw.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7GT2pKgPoMK4tfO-Mciaw.jpg
# Saved -7KmgZsL_yfMig2JUS_BOQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7KmgZsL_yfMig2JUS_BOQ.jpg
# Saved -7NgGYP0Fai6mCBHDdQhrQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7NgGYP0Fai6mCBHDdQhrQ.jpg
# Saved -7pTjgwqg9R8Ww8BbtzXLQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7pTjgwqg9R8Ww8BbtzXLQ.jpg
# Saved -7swnXUmgLHiA06KdhyijQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7swnXUmgLHiA06KdhyijQ.jpg
# Saved -7S_RE3sXEn5O_lUQlVCmA.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7S_RE3sXEn5O_lUQlVCmA.jpg
# Saved -7W3r0wpYUF6I19tyZMiBQ.jpg to C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Photos/extracted_sample_images\-7W3r0wpYUF6I19tyZMiBQ.jpg

# %%
filename = "photos" + ".json"
path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

df_photo = pd.read_json(path, lines=True, chunksize=100000)

photo_chunks = []

for i, chunk in enumerate(df_photo):
    # print(f"Processing chunk {i+1}")
    photo_chunks.append(chunk)
    
    if i == 9:
        break
    
chunk_photo = pd.concat(photo_chunks, ignore_index=True)

chunk_photo.shape
# Out:
# (200100, 4)

# %%
filename = "photos" + ".csv"
out_path = "C:/Users/tokud/OneDrive/Documents/Machine Learning - UCSD Extension Springboard Course/Capstone/Datasets/" + filename

chunk_photo.to_csv(out_path, index=False)
